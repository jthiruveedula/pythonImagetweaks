# %%
from PIL import Image
from PIL import ImageFilter

# %%
im=Image.open('C:/Users/Jagadeesh/Desktop/ca.jpg')

# %%
im.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=1024x768 at 0x2A511CC9C88>

# %%
out = im.filter(ImageFilter.DETAIL)
out.show()

# %%
out = im.point(lambda i: i * 1.5)
out.show()

# %%
from PIL import ImageEnhance

enh = ImageEnhance.Contrast(im)
enh.enhance(2.5).show("30% more contrast")

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
im.show()

# %%
#cropping images
im.crop((100,100,800,500))
# Out:
# <PIL.Image.Image image mode=RGB size=700x400 at 0x2A5100FED08>

# %%
im.rotate(270, expand=True)
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024 at 0x2A510113088>

# %%
im.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x2A510113688>

# %%
#Geometrical transforms
Image.ROTATE_90
Image.FLIP_LEFT_RIGHT
Image.FLIP_TOP_BOTTOM
Image.ROTATE_90
Image.ROTATE_180
Image.ROTATE_270
# Out:
# 2

# %%
im.transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=768x1024 at 0x2A510118488>

# %%
im.size
# Out:
# (960, 720)

# %%
im.height
# Out:
# 720

# %%
im.width
# Out:
# 960

# %%
im.format
# Out:
# 'JPEG'

# %%
#color seperation and merginig
r, g, b = im.split()
im = Image.merge("RGB", (b, g, r))
im.show()

# %%
im.save('new.png')

# %%
#loading image in kears to perform deeplearning functionalities on images
from keras.preprocessing import image

# %%
ca = image.load_img('C:/Users/Jagadeesh/Desktop/ca.jpg', target_size=(200,200))

# %%
type(ca)
# Out:
# PIL.Image.Image

# %%
kim.size
kim.show()
